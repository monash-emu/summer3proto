# %%
from summer3.alt import *
import numpy as np
from jax import numpy as jnp, jit

# %%
nm = NModel(["S", "I", "R"])
nm.stratifications

#Flow("infection", 0.1, {"state": "S"}, {"state": "I"})
# Out:
# {'state': state: ['S', 'I', 'R']}

# %%
nm.stratify(NStrat("age", ["child", "adult","older"]))

#Flow("infection", 0.1, {"state": "S"}, {"state": "I"})
# Maps 1:1
# How do we know?  Source and dest are stratified identically
# Out:
# S [S_child, S_adult, S_older]
# I [I_child, I_adult, I_older]
# R [R_child, R_adult, R_older]

# %%
nm.stratify(NStrat("employment", ["frontline","workplace_other", "low_contact"], {"age": "adult"}))

#Flow("infection", 0.1, {"state": "S"}, {"state": "I"})
# Maps 1:1
# How do we know?  Source and dest are stratified identically
# Out:
# S_adult [S_adult_frontline, S_adult_workplace_other, S_adult_low_contact]
# I_adult [I_adult_frontline, I_adult_workplace_other, I_adult_low_contact]
# R_adult [R_adult_frontline, R_adult_workplace_other, R_adult_low_contact]

# %%
S -> [S_child, S_adult -> [S_adult_frontline, S_adult_workplace_other, S_adult_low_contact], S_older]

# %%
nm.stratify(NStrat("severity", ["asymptomatic","mild", "severe"], {"state": "I"}))

# Flow("infection", 0.1, {"state": "S"}, {"state": "I"})
#    Maps     1:1
#    Source:  unstrat
#    Target:  strat [1:3]
# Default: (1/3.0)
# Out:
# I_child [I_child_asymptomatic, I_child_mild, I_child_severe]
# I_adult_frontline [I_adult_frontline_asymptomatic, I_adult_frontline_mild, I_adult_frontline_severe]
# I_adult_workplace_other [I_adult_workplace_other_asymptomatic, I_adult_workplace_other_mild, I_adult_workplace_other_severe]
# I_adult_low_contact [I_adult_low_contact_asymptomatic, I_adult_low_contact_mild, I_adult_low_contact_severe]
# I_older [I_older_asymptomatic, I_older_mild, I_older_severe]

# %%
(I -> [I_child, I_adult -> [I_adult_frontline, I_adult_workplace_other, I_adult_low_contact], I_older]) * ("severity")
# Out:
#   Cell In[8], line 1
#     -> [S_child, I_adult -> [I_adult_frontline, I_adult_workplace_other, I_adult_low_contact], S_older]
#     ^
# SyntaxError: invalid syntax
