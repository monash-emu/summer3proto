# %%
from jax import grad, jit, lax, numpy as jnp
from jax.random import PRNGKey
import numpy as np
import pandas as pd
from numpyro import distributions as dist

# %%
rate = 0.1

k = PRNGKey(0)
sshape = (16384,)

gsamples = dist.Gamma(rate).sample(k, sshape)
psamples = dist.Poisson(rate).sample(k, sshape)

# %%
gsamples.max()
# Out:
# Array(5.5500417, dtype=float32)
